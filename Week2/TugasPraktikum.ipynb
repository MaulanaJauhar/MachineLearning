# %% [markdown]
# <a href="https://colab.research.google.com/github/MaulanaJauhar/MachineLearning/blob/main/Week2/TugasPraktikum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tugas Praktikum
# ###*Wisconsin Breast Cancer*
# ###**Nama : Jauhar Maulana A'la**
# ###**NIM : 2141720186**
# ###**Kelas : TI -3A**

# %% [markdown]
# ###**Deskripsi Tugas**

# %% [markdown]
# Pada tugas pratikum ini Anda akan menggunakan data "Wisconsin Breast Cancer". Data tersebut terdiri dari 569 data yang digunakan untuk mendiagnonis jenis kanker Malignant (M) dan Benign (B). Tugas Anda adalah,

# %% [markdown]
# 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.
# 2. Lakukan proses encoding pada kolom "diagnosis".
# 3. Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.
# 4. Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.

# %% [markdown]
# ###**Langkah 1**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
data = '/content/drive/MyDrive/ML_2/wbc.csv' # path dataset
df = pd.read_csv(data) # load dataset
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
used_variables = [
    "diagnosis", "radius_mean", "texture_mean", "perimeter_mean", "area_mean",
    "smoothness_mean", "compactness_mean", "concavity_mean",
    "concave points_mean", "symmetry_mean", "fractal_dimension_mean"
]

df_used = df[used_variables]

# Melihat beberapa baris pertama dari DataFrame yang sudah difilter
df_used.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# 0         0.2419                 0.07871
# ...

# %% [markdown]
# ###**Langkah 2**

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
le = LabelEncoder() # membuat objek dari LabelEncoder
df_used['diagnosis'] = le.fit_transform(df_used['diagnosis']) # proses encoding
# Out:
# <ipython-input-27-9964a1953eb8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_used['diagnosis'] = le.fit_transform(df_used['diagnosis']) # proses encoding

# %% [markdown]
# ###**Langkah 3**

# %%
# Impor pustaka yang dibutuhkan
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Baca file csv ke dalam dataframe pandas
df = pd.read_csv('/content/drive/MyDrive/ML_2/wbc.csv')

# Pilih semua kolom numerik
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Buat objek StandardScaler
scaler = StandardScaler()

# Sesuaikan dan transformasikan data numerik
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# Tampilkan dataframe yang telah distandarkan
print(df)

# std = StandardScaler()
# df_used['radius_mean'] = std.fit_transform(df_used[['radius_mean']])
# df_used['texture_mean'] = std.fit_transform(df_used[['texture_mean']])
# df_used['perimeter_mean'] = std.fit_transform(df_used[['perimeter_mean']])
# df_used['area_mean'] = std.fit_transform(df_used[['area_mean']])
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   -0.236405         M     1.097064     -2.073335        1.269934   0.984375
# 1   -0.236403         M     1.829821     -0.353632        1.685955   1.908708
# 2    0.431741         M     1.579888      0.456187        1.566503   1.558884
# 3    0.432121         M    -0.768909      0.253732       -0.592687  -0.764464
# 4    0.432201         M     1.750297     -1.151816        1.776573   1.826229
# ..        ...       ...          ...           ...             ...        ...
# 564 -0.235732         M     2.110995      0.721473        2.060786   2.343856
# 565 -0.235730         M     1.704854      2.085134        1.615931   1.723842
# 566 -0.235727         M     0.702284      2.045574        0.672676   0.577953
# 567 -0.235725         M     1.838341      2.336457        1.982524   1.735218
# 568 -0.242406         B    -1.808401      1.221792       -1.814389  -1.347789
#
# ...

# %%
df_used.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# 0         0.2419                 0.07871
# ...

# %% [markdown]
# ###**Langkah 4**

# %%
from sklearn.model_selection import train_test_split
# Split data training dan testing
# Rasio yang akan kita gunakan adalah 8:2
df_train, df_test = train_test_split(df_used, test_size=0.2, random_state=42)

# df_train akan berisi 80% data, df_test akan berisi 20% data
# random_state digunakan untuk memastikan bahwa pembagian data adalah sama setiap kali kode dijalankan

# Mencetak ukuran dari data training dan testing
print("Ukuran Data Training:", df_train.shape)
print("Ukuran Data Testing:", df_test.shape)
# Out:
# Ukuran Data Training: (455, 11)
# Ukuran Data Testing: (114, 11)

# %%
df_train.head()
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 68           0        9.029         17.33           58.79      250.5
# 181          1       21.090         26.57          142.70     1311.0
# 63           0        9.173         13.86           59.20      260.9
# 248          0       10.650         25.22           68.01      347.0
# 60           0       10.170         14.88           64.55      311.9
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 68           0.10660           0.14130         0.31300              0.04375
# 181          0.11410           0.28320         0.24870              0.14960
# 63           0.07721           0.08751         0.05988              0.02180
# 248          0.09657           0.07234         0.02379              0.01615
# 60           0.11340           0.08061         0.01084              0.01290
#
#      symmetry_mean  fractal_dimension_mean
# 68          0.2111                 0.08046
# ...

# %%
df_test.head()
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 204          0        12.47         18.60           81.09      481.9
# 70           1        18.94         21.31          123.60     1130.0
# 131          1        15.46         19.48          101.70      748.9
# 431          0        12.40         17.68           81.47      467.8
# 540          0        11.54         14.44           74.65      402.9
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 204          0.09965            0.1058         0.08005              0.03821
# 70           0.09009            0.1029         0.10800              0.07951
# 131          0.10920            0.1223         0.14660              0.08087
# 431          0.10540            0.1316         0.07741              0.02799
# 540          0.09984            0.1120         0.06737              0.02594
#
#      symmetry_mean  fractal_dimension_mean
# 204         0.1925                 0.06373
# ...
